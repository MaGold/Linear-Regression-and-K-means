# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
sns.set(color_codes=True)

# %%
def plotIt(x_train, y_train, x_test, y_test):
    fig = plt.figure(figsize=(8,6))
    ax = fig.add_subplot(111)

    colors = np.array(["blue", "orange"])
    #plot training data:
    #ax.plot(greens[:,0],greens[:,1], 'o', markersize=8, markeredgewidth=4, markerfacecolor='none', markeredgecolor='orange')
    #ax.plot(blues[:,0],blues[:,1], 'o', markersize=8, markeredgewidth=4, markerfacecolor='none', markeredgecolor='b')
    plt.scatter(x_train[:, 0], x_train[:, 1], color = colors[y_train.astype(int)], markerstyle='o')

    plt.xlim([-4,4])
    plt.ylim([-4,4])

    
    plt.scatter(x_test[:, 0], x_test[:, 1], color = colors[y_test.astype(int)], markerstyle='o')
    #plot test data:
    #for x,y in zip(x_test, y_test):
        #if y<=0.5:
            #ax.plot(x[0], x[1], '.', color='blue', markersize=5)
        #else:
            #ax.plot(x[0], x[1], '.', color='orange', markersize=5)

# %% [markdown]
# #Generate training data

# %%
greens = []
blues = []

n = 1000 # number of points per class
D = 2 # dimensionality
K = 2 # number of classes
X = np.zeros((n*K,D)) # data matrix (each row = single example)
y = np.zeros(n*K, dtype='uint8') # class labels
for j in xrange(K):
    ix = range(n*j,n*(j+1))
    r = 4*np.linspace(0.0,1,n) # radius
    t = np.linspace(j*4,(j+1)*4,n) + np.random.randn(n)*0.39 # theta
    X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
    y[ix] = j
    #if j:
        #greens.append(np.c_[r*np.sin(t), r*np.cos(t)])
    #else:
        #blues.append(np.c_[r*np.sin(t), r*np.cos(t)])
# lets visualize the data:
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)

# %%
#blues = blues[0]
#greens = greens[0]

# %%
x_train = X
y_train = y

# %% [markdown]
# ##generate some test data

# %%
N=2*n
x_test = np.array([0,0])
for x in np.linspace(-4, 4, 500):
    for y in np.linspace(-4, 4, 500):
        x_test = np.vstack((x_test, np.array([x,y])))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-201-d7f4fb10cb2d> in <module>()
#       3 for x in np.linspace(-4, 4, 500):
#       4     for y in np.linspace(-4, 4, 500):
# ----> 5         x_test = np.vstack((x_test, np.array([x,y])))
#       6
#
# C:\Users\Me\Anaconda\lib\site-packages\numpy\core\shape_base.pyc in vstack(tup)
#     226
#     227     """
# --> 228     return _nx.concatenate([atleast_2d(_m) for _m in tup], 0)
#     229
#     230 def hstack(tup):
#
# KeyboardInterrupt:

# %% [markdown]
# #SGDClassifier

# %%
from sklearn.linear_model import SGDClassifier

SGD = SGDClassifier(loss="log", penalty="none", n_iter=100000)
SGD.fit(x_train, np.ravel(y_train))

# %%
beta_SGD = SGD.coef_.T
print beta_SGD
print SGD.intercept_

# %%
y_testSGD = SGD.predict(x_test)

# %%
plotIt(x_train, y_train, x_test, y_testSGD)

# %% [markdown]
# #LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

LGSTC = LogisticRegression(solver = "liblinear")
LGSTC.fit(x_train, np.ravel(y_train))
beta_LGSTC = LGSTC.coef_.T
y_testLogistic = LGSTC.predict(x_test)

# %%
plotIt(x_train, y_train, x_test, y_testLogistic)

# %% [markdown]
# #Modified LinearRegression

# %%
from sklearn import linear_model
LREG = linear_model.LinearRegression()
LREG.fit(x_train, y_train)

beta_LREG = LREG.coef_.T
y_testLREG = LREG.predict(x_test)

# %%
plotIt(x_train, y_train, x_test, y_testLREG)

# %% [markdown]
# #DECISION TREE

# %%
from sklearn import tree
TREE = tree.DecisionTreeClassifier()
TREE.fit(x_train, y_train)

# %%
y_testTREE = TREE.predict(x_test)

# %%
plotIt(x_train, y_train, x_test, y_testTREE)

# %% [markdown]
# #Random Forest

# %%
from sklearn import ensemble
FOREST = ensemble.RandomForestClassifier()
FOREST.fit(x_train, y_train)

# %%
y_testFOREST = FOREST.predict(x_test)

# %%
plotIt(x_train, y_train, x_test, y_testFOREST)
